# %%
import pandas as pd

df=pd.read_csv("global_mainline.csv")

pd.set_option('display.max_columns', None)

df
# Out:
# C:\Users\farza\AppData\Local\Temp\ipykernel_38224\2919966997.py:3: DtypeWarning: Columns (45,62,64,66,68,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("global_mainline.csv")
#             Name                     Email    Financial Status  \
# 0       NL524626     contact@sneakmart.com                paid
# 1       NL524625     contact@sneakmart.com                paid
# 2       NL524625     contact@sneakmart.com                 NaN
# 3       NL524620     contact@sneakmart.com                paid
# 4       NL524618        bramanys@gmail.com                 NaN
# ...          ...                       ...                 ...
# 171249   #260664        joppesoons@live.nl  partially_refunded
# 171250   #260664        joppesoons@live.nl                 NaN
# 171251   #260664        joppesoons@live.nl                 NaN
# 171252   #260664        joppesoons@live.nl                 NaN
# ...

# %%
a = df[''].unique()
print a.sort()
